# %%
import sys 
import os
import pprint
sys.path.append(os.path.join(os.getcwd(), "notebook"))
from src.evaluacion import mejor_equipo_ronda
from src.acumulados import inicializar_acumulados, actualizar_acumulados, equipo_menos_errores, promedio_por_ronda
from src.resultado import mostrar_tabla
from pprint import pprint

#----rondas resultados--------:

evaluaciones = [
    # Ronda 1
        { 'EquipoA': {'innovacion': 2, 'presentacion': 1, 'errores': True},
          'EquipoB': {'innovacion': 1, 'presentacion': 0, 'errores': False},
          'EquipoC': {'innovacion': 1, 'presentacion': 2, 'errores': True},
          'EquipoD': {'innovacion': 0, 'presentacion': 1, 'errores': False},
          'EquipoE': {'innovacion': 1, 'presentacion': 1, 'errores': False}
          },
    # Ronda 2
        {'EquipoA': {'innovacion': 0, 'presentacion': 2, 'errores': False},
         'EquipoB': {'innovacion': 2, 'presentacion': 0, 'errores': True},
         'EquipoC': {'innovacion': 1, 'presentacion': 1, 'errores': False},
         'EquipoD': {'innovacion': 2, 'presentacion': 1, 'errores': True},
         'EquipoE': {'innovacion': 0, 'presentacion': 1, 'errores': False}
         },
    # Ronda 3
        {'EquipoA': {'innovacion': 3, 'presentacion': 2, 'errores': False},
         'EquipoB': {'innovacion': 1, 'presentacion': 1, 'errores': True},
         'EquipoC': {'innovacion': 2, 'presentacion': 0, 'errores': False},
         'EquipoD': {'innovacion': 1, 'presentacion': 3, 'errores': True},
         'EquipoE': {'innovacion': 2, 'presentacion': 2, 'errores': False}
         },
    # Ronda 4
        {'EquipoA': {'innovacion': 1, 'presentacion': 3, 'errores': True},
         'EquipoB': {'innovacion': 2, 'presentacion': 2, 'errores': False},
         'EquipoC': {'innovacion': 3, 'presentacion': 1, 'errores': False},
         'EquipoD': {'innovacion': 0, 'presentacion': 2, 'errores': True},
         'EquipoE': {'innovacion': 2, 'presentacion': 0, 'errores': False}
         },
    # Ronda 5
        {'EquipoA': {'innovacion': 2, 'presentacion': 2, 'errores': False},
         'EquipoB': {'innovacion': 1, 'presentacion': 3, 'errores': True},
         'EquipoC': {'innovacion': 0, 'presentacion': 2, 'errores': False},
         'EquipoD': {'innovacion': 3, 'presentacion': 1, 'errores': False},
         'EquipoE': {'innovacion': 2, 'presentacion': 3, 'errores': True}
         }
]

# ----FLUJO PRINCIPAL--------:

## Inicializamos acumulados con los equipos de la primera ronda

acumulados = inicializar_acumulados(evaluaciones)

# Procesamos cada ronda

nro_Ronda=1

for ronda in evaluaciones:
    mejor = mejor_equipo_ronda(ronda)
    acumulados = actualizar_acumulados(acumulados, ronda, mejor)
    mostrar_tabla(acumulados, nro_Ronda, mejor)
    nro_Ronda += 1

# ---- Estadísticas finales (Ejercicios Adicionales) ----

# 1) Equipo con menos errores

menos_err, cant_err = equipo_menos_errores(acumulados)
print(f"\nEquipo con menos errores: {menos_err} ({cant_err} errores)")


# 2) Promedio de puntos por ronda

promedios = promedio_por_ronda(acumulados, evaluaciones)
print("\nPromedio de puntos por ronda:") 
print(promedios)
# Out:
# Ronda 1
# Mejor Equipo de la Ronda: EquipoA
#
# Ranking Actualizado
#
# Equipo    Innovacion  Presentacion  Errores Mejores Equipos Puntos Total
# ----------------------------------------------------------------------
# EquipoA   2           1             1       1               6
# EquipoC   1           2             1       0               4
# EquipoE   1           1             0       0               4
# EquipoB   1           0             0       0               3
# EquipoD   0           1             0       0               1
#
# Ronda 2
# Mejor Equipo de la Ronda: EquipoD
#
# Ranking Actualizado
#
# Equipo    Innovacion  Presentacion  Errores Mejores Equipos Puntos Total
# ----------------------------------------------------------------------
# EquipoA   2           3             1       1               8
# EquipoB   3           0             1       0               8
# EquipoC   2           3             1       0               8
# EquipoD   2           2             1       1               7
# EquipoE   1           2             0       0               5
#
# Ronda 3
# Mejor Equipo de la Ronda: EquipoA
#
# Ranking Actualizado
#
# Equipo    Innovacion  Presentacion  Errores Mejores Equipos Puntos Total
# ----------------------------------------------------------------------
# EquipoA   5           5             1       2               19
# EquipoC   4           3             1       0               14
# EquipoE   3           4             0       0               13
# EquipoD   3           5             2       1               12
# EquipoB   4           1             2       0               11
#
# Ronda 4
# Mejor Equipo de la Ronda: EquipoC
#
# Ranking Actualizado
#
# Equipo    Innovacion  Presentacion  Errores Mejores Equipos Puntos Total
# ----------------------------------------------------------------------
# EquipoA   6           8             2       2               24
# EquipoC   7           4             1       1               24
# EquipoB   6           3             2       0               19
# EquipoE   5           4             0       0               19
# EquipoD   3           7             3       1               13
#
# Ronda 5
# Mejor Equipo de la Ronda: EquipoD
#
# Ranking Actualizado
#
# Equipo    Innovacion  Presentacion  Errores Mejores Equipos Puntos Total
# ----------------------------------------------------------------------
# EquipoA   8           10            2       2               32
# EquipoE   7           7             1       0               27
# EquipoC   7           6             1       1               26
# EquipoB   7           6             3       0               24
# EquipoD   6           8             3       2               23
#
# Equipo con menos errores: EquipoC (1 errores)
#
# Promedio de puntos por ronda:
# {'EquipoA': 6.4, 'EquipoB': 4.8, 'EquipoC': 5.2, 'EquipoD': 4.6, 'EquipoE': 5.4}
